# %% [markdown]
# <a href="https://colab.research.google.com/github/G0rav/Tiramisu/blob/main/Tiramisu103.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://github.com/0bserver07/One-Hundred-Layers-Tiramisu

# %%
import tensorflow as tf

# %%
import json
  
# Opening JSON file
f = open('/content/tiramisu_fc_dense103_model.json',)
  
# returns JSON object as 
# a dictionary
data = json.load(f)

print(data) 
# Iterating through the json
# list
#for i in data['emp_details']:
    #print(i)
  
# Closing file
f.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-2d7ab7691991> in <module>()
#       2
#       3 # Opening JSON file
# ----> 4 f = open('https://github.com/0bserver07/One-Hundred-Layers-Tiramisu/blob/master/tiramisu_fc_dense103_model.json',)
#       5
#       6 # returns JSON object as
#
# FileNotFoundError: [Errno 2] No such file or directory: 'https://github.com/0bserver07/One-Hundred-Layers-Tiramisu/blob/master/tiramisu_fc_dense103_model.json'

# %%
data = json.dumps(data)
loaded_data = json.loads(data)

# %%
type(data)
# Out:
# str

# %%
loaded_model = tf.keras.models.model_from_json(data)
loaded_model

# %%
loaded_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 224, 224, 48)      1344
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 224, 224, 48)      896
# _________________________________________________________________
# activation_1 (Activation)    (None, 224, 224, 48)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 224, 224, 112)     48496
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 224, 224, 112)     0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 224, 224, 112)     896
# _________________________________________________________________
# activation_2 (Activation)    (None, 224, 224, 112)     0
# ...

# %%
img_file = "tiramisu_fc_dense103.png"
tf.keras.utils.plot_model(loaded_model, to_file= img_file, show_shapes=True, show_layer_names=True)
# Out:
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.740849 to fit
